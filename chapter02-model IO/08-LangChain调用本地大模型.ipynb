# %% [markdown]
# ## LangChain调用本地大模型

# %%
from langchain_ollama import ChatOllama
import os
import dotenv
dotenv.load_dotenv()
# os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY1")
# os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL1")
model = ChatOllama(model="deepseek-r1:8b")

res=model.invoke('什么事大模型')
print(res.content)
# Out:
# <think>
# 嗯，用户问的是“什么事大模型，应该是想了解大模型相关的内容。用户可能对人工智能领域不太熟悉或者刚接触这个概念，所以需要从基础解释清楚易懂。
#
# 首先得入手。大模型AI模型就是机器学习的核心是深度学习发展来的参数量大模型参数多数据训练数据需要算力强算力强比如Transformer架构这些关键。得讲清楚。GPTERNLP Transformer Transformer区别Transformer特点像BERT这些基础。还要例子说明应用比如ChatGPT应用ChatGPT区别比如对话。
#
# 用户可能想知道为什么厉害。用中文场景未来趋势比如翻译写作编程这些。
#
# 回答结构分层：定义基础发展架构技术例子应用影响未来。避免太技术细节但深度。用户可能不懂术语多用例子帮助理解。中文术语说明白话。需要例子比如用ChatGPT翻译例子。最后总结大模型就是参数多数据训练复杂模型处理强算力智能应用广现在用很火未来发展方向。
# </think>
# </think>
# 好的，我们来聊聊“大模型（Large Model，通常指的是人工智能领域中的“大模型）吧！😊
#
# ## 你可能你是想问的是 **“大模型**大模型（Large Model**”**，指的是人工智能中的**大语言模型（Large Model**？
#
# ##，比如像ChatGPT（ChatG、GPT、G、文心一言一言一言、Claude这些？
#
# 如果是的话，那确实没错！
#
# **大模型就是一种非常厉害的AI语言模型，能做很多事！
#
# ---
#
# ###  1. **是什么？**
# 大模型？
# 是能理解语言文字、生成回答问题、翻译、对话、写文章、编程、写代码、创作等AI助手的AI。它们叫大模型。
#
# 2017B以上参数（亿参数，几百亿）
#
# ### 参数多训练需数据算力强（GPU）算力（大型集群）和TPU算力（显卡）架构（多并行训练）
#
# #### 像结构：Transformer大核心是Transformer，如ERN，BERT、GPT模型基于Transformer改进
#
# ###例子ChatGPT例子：
# GPT（ChatGPT、Cla（Chat、文一言一言、Cla、Kimi）###用作事：回答问题、创作、对话、编程、翻译、编程、总结、解释、翻译、摘要、改写诗、翻译、写文章、绘图（结合多模）###用（如绘画文生图像）
#
# ###用DALLM通用多用领域用现在用编程写代码、法律、医学等
#
# ###用
#
# ###总结
# 模型大模型，就是强用大、算力训练、参数、多数据、结构好用广泛用、未来，发展快
#
# 如果你是想入行，可以学学学Python学Python、学框架PyTorch深度学习Transformer等入门
