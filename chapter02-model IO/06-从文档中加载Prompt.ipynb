# %% [markdown]
# * 举例1:从物理磁盘的yaml文件中读取prompt数据

# %%
# 举例一：读取yaml文件
from langchain_core.prompts import load_prompt
import dotenv
dotenv.load_dotenv()

lp=load_prompt("prompt.yaml",encoding="utf-8")

print(lp.format(name='年轻人',what='滑稽'))
# Out:
# 请年轻人讲一个滑稽的故事

# %%
# 举例二：读取json文件

from langchain_core.prompts import load_prompt
import dotenv
dotenv.load_dotenv()

lp=load_prompt("prompt.json",encoding="utf-8")

print(lp.format(name='年轻人',what='滑稽'))
# Out:
# 请年轻人讲一个滑稽的故事
