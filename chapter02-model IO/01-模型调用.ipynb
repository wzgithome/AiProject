# %%
from langchain_openai import ChatOpenAI
import os
import dotenv
dotenv.load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY2")
os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL2")
llm = ChatOpenAI(
    model='qwen3.5-plus',
)
res=llm.invoke('大模型是什么')
# res=llm.invoke('根据IP是192.168.0.158查询所在位置')
print(res.content)
# Out:
# 无法通过 **192.168.0.158** 这个 IP 地址查询到具体的地理位置。
#
# **原因如下：**
#
# 1.  **这是私有 IP 地址（Private IP）：**
#     *   `192.168.x.x` 是国际互联网工程任务组（IETF）保留给**局域网（LAN）** 使用的私有地址段。
#     *   它通常用于家庭路由器、公司内部网络或校园网内部。
#     *   全球有数以亿计的设备（手机、电脑、智能家居等）都在使用这个相同的 IP 地址段，但它们都位于不同的物理位置。
#
# 2.  **不在公共互联网上路由：**
#     *   私有 IP 地址不能在公共互联网上直接访问，因此公共的 IP 地理位置数据库中没有它的记录。
#
# **如果您想查询当前的网络位置：**
#
# 您需要查询的是您的 **公网 IP 地址（Public IP / WAN IP）**。您可以尝试以下方法：
#
# 1.  在浏览器中搜索关键词 **"IP"** 或 **"我的 IP"**。
# 2.  访问专门的查询网站（如 `ip138.com` 或 `whatismyip.com`）。
# 3.  这些网站会显示您路由器对外的公网 IP，那个 IP 才可以用来大致定位您的城市或运营商信息。
#
# **总结：** `192.168.0.158` 只是您设备在本地网络（比如您家里 Wi-Fi）中的“门牌号”，而不是您家在地球上的“地址”。
