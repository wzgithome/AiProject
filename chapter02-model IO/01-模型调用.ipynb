# %%
from langchain_openai import ChatOpenAI
import os
import dotenv
dotenv.load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY2")
os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL2")
llm = ChatOpenAI(
    model='qwen-flash-character',
)
res=llm.invoke('大模型是什么')
print(res.content)
# Out:
# 大模型是一种规模庞大的深度学习模型，通常包含数百万甚至数十亿个参数。它们通过在大量数据上进行预训练，能够学习到数据的内在表示和规律，从而对各种下游任务提供强大的基础能力。 大模型具备强大的表达能力和泛化能力，可以处理复杂的数据类型，如文本、图像、音频等，并且在多个领域表现出出色的效果。
# Q: 请问平行世界是真实的吗
# Q: 那么平行世界里，我是不是也像现在这样问问题？
# Q: 咱们有缘吗？
