# %%
from langchain_openai import ChatOpenAI
import os
import dotenv
dotenv.load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY2")
os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL2")
llm = ChatOpenAI(
    model='qwen3.6-plus',
)
res=llm.invoke('大模型是什么')
# res=llm.invoke('根据IP是192.168.0.158查询所在位置')
print(res.content)
# Out:
# “大模型”（Large Model）是近年来人工智能领域的核心概念，通常指**基于深度学习训练出的超大规模神经网络**。它最常被用来指代**大语言模型（LLM）**，但广义上也包含图像、音频、视频等多模态基础模型。
#
# ### 🔍 为什么叫“大”？
# “大”主要体现在三个维度：
# 1. **参数量大**：通常从数十亿（B）到数千亿甚至上万亿。参数相当于模型的“记忆与计算单元”，规模越大，表达能力越强。
# 2. **训练数据大**：使用互联网文本、书籍、论文、代码、高质量图像等海量数据（通常达TB甚至PB级）。
# 3. **算力需求大**：训练需数千至上万张高端GPU，耗时数周至数月，成本可达数千万至数亿美元。
#
# ### 💡 核心特点与能力
# - **通用性强**：一个模型可完成翻译、写作、编程、问答、推理等多种任务，无需为每个任务单独训练。
# - **零样本/少样本学习**：仅通过自然语言提示（Prompt），就能理解并完成未见过的任务。
# - **涌现能力（Emergent Abilities）**：当模型规模突破某个临界点后，会突然具备小模型不具备的复杂能力（如数学推理、代码调试、逻辑链思考）。
# - **可微调适配**：通过指令微调（SFT）、人类反馈强化学习（RLHF）或领域数据继续训练，可快速变成医疗、法律、金融等垂直行业模型。
#
# ### ⚙️ 工作原理（极简版）
# - 底层多采用 **Transformer 架构**，核心机制是“注意力（Attention）”，能动态捕捉文本中长距离的语义关联。
# - 训练分两步：
#   1. **预训练**：在海量无标注数据上学习“预测下一个词/标记”，掌握语言规律与世界知识。
#   2. **对齐微调**：用高质量指令数据和人类偏好反馈，让模型输出更安全、有用、符合人类意图的结果。
#
# ### 🌐 常见类型与应用
# | 类型 | 代表 | 典型应用 |
# |------|------|----------|
# | 纯文本大模型 | GPT-4、通义千问、Claude、文心一言 | 智能对话、内容创作、代码生成、数据分析 |
# | 多模态大模型 | Gemini、Qwen-VL、Sora、Kling | 图文理解与生成、视频生成、语音交互、具身智能 |
# | 行业/垂直大模型 | 医疗大模型、金融大模型、法律大模型 | 专业文档审阅、风险评估、辅助诊疗、合规审查 |
#
# ### ⚠️ 重要局限性
# - **幻觉（Hallucination）**：可能生成看似合理但事实错误的内容。
# - **依赖数据质量**：训练数据中的偏见、错误或滞后信息会被模型继承。
# - **缺乏真实理解**：本质是统计模式匹配，不具备人类的因果推理、物理常识或主观意识。
# - **部署成本高**：推理仍需较强算力，端侧落地需模型压缩、蒸馏等技术。
#
# ### 📌 一句话总结
# 大模型是通过“海量数据+巨大算力+先进架构”训练出的**通用AI底座**，它让机器从“只能做特定任务”迈向“能听懂人话、举一反三”，正在成为新一代人机交互与产业智能化的核心基础设施。
#
# 如需了解某类大模型的技术细节、如何调用、或与传统AI的区别，可告诉我你的具体方向。
