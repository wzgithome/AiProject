# %%
from langchain_openai import ChatOpenAI
import os
import dotenv
dotenv.load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY4")
os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL4")
llm = ChatOpenAI(
    model='GLM-4.7-Flash',
)
res=llm.invoke('大模型是什么')
# res=llm.invoke('根据IP是192.168.0.158查询所在位置')
print(res.content)
# Out:
# **大模型（Large Model，通常指大语言模型 LLM）**，通俗来说，就是**人工智能（AI）的一种超级“大脑”**。
#
# 它通过阅读海量的文字（甚至包括代码、图片等数据），学会了人类的知识和逻辑，从而能够像人一样进行对话、写作、翻译、编程，甚至画画。
#
# 为了让你更直观地理解，我们可以从以下几个维度来拆解：
#
# ### 1. 为什么叫“大”模型？
# 它的“大”主要体现在两个方面：
#
# *   **数据量大：** 它像是一个读完了互联网上几乎所有书籍、文章、论坛帖子的人。它见过无数种语境和表达方式。
# *   **参数量大：** 模型内部有数十亿甚至数万亿个参数（可以理解为神经元的连接权重）。这些参数像是一张极其复杂的“地图”，记录了它学到的所有规律和知识。
#
# ### 2. 它是如何工作的？（类比）
# 你可以把大模型想象成一个**博览群书的“超级实习生”**：
# *   它不是死记硬背，而是通过**模式识别**来学习。
# *   当你问它问题时，它会根据它学过的“地图”，在概率上计算出下一个最可能出现的字是什么，从而生成回答。
#
# ### 3. 它能做什么？
# 大模型的能力非常强大，通常被称为**涌现能力**，即当规模足够大时，它会突然展现出超越预料的智能：
# *   **内容创作：** 写文章、写诗、写代码、写邮件。
# *   **知识问答：** 解答问题、翻译语言、总结长文。
# *   **逻辑推理：** 做数学题、分析问题、制定计划。
# *   **多模态：** 现在的很多大模型不仅能看懂文字，还能看懂图片（如 GPT-4V, Claude 3.5 Sonnet）。
#
# ### 4. 例子
# 你肯定听说过这些名字，它们都是大模型的代表：
# *   **国外的：** ChatGPT (基于 GPT-4), Claude, Llama。
# *   **国内的：** 文心一言, 通义千问, 讯飞星火, 智谱 AI (ChatGLM)。
#
# ### 总结
# 大模型就是**AI 领域的一次技术飞跃**。它让计算机第一次具备了真正的“理解”和“生成”能力，被广泛认为是人工智能发展的重要里程碑。
