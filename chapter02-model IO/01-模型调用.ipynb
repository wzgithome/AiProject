# %%
from langchain_openai import ChatOpenAI
import os
import dotenv
dotenv.load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY4")
os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL4")
llm = ChatOpenAI(
    model='GLM-4.7-Flash',
)
res=llm.invoke('大模型是什么')
# res=llm.invoke('根据IP是192.168.0.158查询所在位置')
print(res.content)
# Out:
# **大模型**，通常指的是**大规模预训练模型**（Large-scale Pre-trained Model），最常见的是**大语言模型**（Large Language Model, LLM）。
#
# 为了让你更容易理解，我们可以把大模型想象成一个**“读过万卷书、行过万里路”的超级大脑**。
#
# 以下是关于大模型的通俗解释：
#
# ### 1. 核心构成：为什么叫“大”？
# 大模型之所以“大”，主要体现在三个方面：
# *   **数据量大：** 它的“训练教材”是海量的互联网文本、书籍、代码和百科全书。比如GPT-4的训练数据可能包含了人类互联网上几乎所有的公开文本。
# *   **参数量大：** 模型的参数就像大脑里的神经元连接。参数越多，模型对世界的理解就越细腻。大模型的参数量从几十亿（Billion）级到万亿（Trillion）级不等。
# *   **算力需求大：** 训练这样一个模型需要成千上万张高性能显卡（GPU）运行数月甚至数年。
#
# ### 2. 它是怎么“学会”东西的？（原理）
# 大模型并不是像人类一样通过逻辑推理来学习，而是通过**“概率预测”**来学习的。
#
# *   **预训练（读书）：** 在这个阶段，模型像读一本厚厚的书一样，阅读海量数据。它的任务是：**根据前面的话，预测下一个字/词/符号是什么**。比如看到“床前明月”，它需要预测出“光”。通过这种无数次、海量的预测训练，模型学会了语法、逻辑、事实知识和语言风格。
# *   **微调（教书）：** 预训练完成后，模型虽然知识广博，但可能不会听人指令（比如不会回答“帮我写首诗”）。这时候，工程师会用人类写好的“问答对”对它进行训练，并加入“人类反馈强化学习”（RLHF），让它学会如何更好地回答问题、遵守规则、拒绝危险请求。
#
# ### 3. 它能做什么？
# 大模型具有强大的**泛化能力**，即它学到了通用的规律，可以应用到很多不同的任务上，不需要为每个任务单独训练：
# *   **内容创作：** 写文章、写代码、写诗歌、写邮件。
# *   **逻辑推理：** 解决数学题、分析问题、制定计划。
# *   **语言翻译：** 在多种语言间互译。
# *   **多模态（未来趋势）：** 现在的先进大模型不仅能处理文字，还能看图、听音、甚至生成视频。
#
# ### 4. 举个简单的例子
# 如果你把大模型比作一个**学生**：
# *   **普通AI模型**就像一个只学过乘法口诀表的学生。
# *   **大模型**就像一个读遍了图书馆所有书籍、博览群书的学生。
#
# 当你要它写一篇关于“量子力学在农业中的应用”的文章时，普通学生可能写不出来，但大模型学生可以通过它学到的海量知识，迅速组合出一篇结构完整、逻辑通顺的文章。
#
# ### 5. 代表产品
# 目前最著名的大模型包括：
# *   **国外：** GPT-4（OpenAI）、Claude（Anthropic）、Llama（Meta）等。
# *   **国内：** 文心一言（百度）、通义千问（阿里）、Kimi（月之暗面）、智谱清言等。
#
# **总结：**
# 大模型是一种基于海量数据和强大算力训练出来的深度学习技术，它具备了类似人类的语言理解、逻辑推理和内容生成能力，是目前人工智能领域最前沿的技术突破。
