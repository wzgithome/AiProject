# %%
# 使用Python自己构建一个记忆Demo
from langchain_core.messages import AIMessage, HumanMessage
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

from langchain_core.output_parsers import StrOutputParser
import os
import dotenv

dotenv.load_dotenv(dotenv_path='../chapter02-model IO/.env')
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY2")
os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL2")

model =  ChatOpenAI(
    model='tongyi-xiaomi-analysis-pro',
    temperature=0.6
)

def chat_with_model(answer):
    # 2、提供提示词模版
    prompt = ChatPromptTemplate.from_messages([
        ("system", "You are a helpful assistant."),
        ("human", "{question}")
    ])
    while True:
        chain=prompt|model

        response=chain.invoke({"question":answer})

        # 输出大模型的响应
        print(f'模型回复：{response.content}')

        # 继续获取用户的问题
        user_input=input('您还有其他问题吗?(输入"退出"时，结束会话)')

        if user_input=='退出':
            break

        prompt.messages.append(AIMessage(content=response.content))
        prompt.messages.append(HumanMessage(content=user_input))


chat_with_model('你好')
# Out:
# 模型回复：你好！有什么我可以帮助你的吗？
# 模型回复：你好！Python 语言在多个排行榜上都名列前茅，例如在 TIOBE 指数和 PYPL 指数中，Python 都是排名第一的编程语言。Python 之所以如此受欢迎，是因为它具有简洁、易读、易学的特点，同时拥有强大的功能和广泛的应用领域，如数据分析、人工智能、Web 开发等。如果你对学习 Python 或者使用 Python 进行项目开发有任何问题，欢迎随时向我提问！
# 模型回复：Java 语言在编程语言排行榜上通常排名第二或第三。例如，在 TIOBE 指数中，Java 通常排在 Python 之后，位居第二；而在 PYPL 指数中，Java 有时会排在 Python 和 JavaScript 之后，位居第三。Java 是一种广泛使用的面向对象的编程语言，适用于企业级应用、Android 应用开发、Web 开发等领域。如果你对 Java 有任何问题，欢迎随时向我提问！
# 模型回复：Python 之所以排名第一，主要有以下几个原因：
#
# 1. **易学性**：Python 语法简洁明了，易于学习，适合编程初学者入门。
#
# 2. **强大的功能**：Python 拥有丰富的标准库和第三方库，可以轻松实现各种功能，如数据分析、机器学习、Web 开发等。
#
# 3. **广泛的应用领域**：Python 在多个领域都有广泛的应用，如科学计算、数据分析、人工智能、Web 开发、自动化运维等。
#
# 4. **社区支持**：Python 拥有庞大的开发者社区，可以提供丰富的资源和支持，如教程、文档、开源项目等。
#
# 5. **跨平台性**：Python 可以在多种操作系统上运行，如 Windows、Linux、macOS 等，具有良好的跨平台性。
#
# 6. **高效性**：Python 的解释器和虚拟机经过优化，可以提供较高的执行效率。
#
# 7. **可扩展性**：Python 可以与其他语言（如 C、C++）进行交互，可以方便地扩展和集成其他语言的库和模块。
#
# 综上所述，Python 的易学性、强大的功能、广泛的应用领域、社区支持、跨平台性、高效性和可扩展性，使其成为排名第一的编程语言。
